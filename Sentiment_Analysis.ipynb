# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting nltk>=3.9 (from textblob)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk>=3.9->textblob)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk>=3.9->textblob)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk>=3.9->textblob)
#   Downloading regex-2025.11.3-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk>=3.9->textblob)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\p sudarshan\appdata\local\programs\python\python311\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    --------------------------------- ------ 524.3/624.3 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 624.3/624.3 kB 1.9 MB/s  0:00:00
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 1.7 MB/s  0:00:00
# Downloading regex-2025.11.3-cp311-cp311-win_amd64.whl (277 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk, textblob
#
#    ------ --------------------------------- 1/6 [regex]
#    ------------- -------------------------- 2/6 [joblib]
#    -------------------- ------------------- 3/6 [click]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    --------------------------------- ------ 5/6 [textblob]
#    ---------------------------------------- 6/6 [textblob]
#
# Successfully installed click-8.3.1 joblib-1.5.2 nltk-3.9.2 regex-2025.11.3 textblob-0.19.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from textblob import TextBlob

# %%
data = {
    "Review": [
        "This product is amazing",
        "Very bad quality",
        "I am happy with the service",
        "Worst experience ever",
        "Average product"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                         Review
# 0      This product is amazing
# 1             Very bad quality
# 2  I am happy with the service
# 3        Worst experience ever
# 4              Average product

# %%
from textblob import TextBlob

def get_sentiment(review):
    polarity = TextBlob(review).sentiment.polarity
    
    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df["Sentiment"] = df["Review"].apply(get_sentiment)
df
# Out:
#                         Review Sentiment
# 0      This product is amazing  Positive
# 1             Very bad quality  Negative
# 2  I am happy with the service  Positive
# 3        Worst experience ever  Negative
# 4              Average product  Negative

# %%
import matplotlib.pyplot as plt

df["Sentiment"].value_counts().plot(kind="bar")
plt.title("Sentiment Analysis of Customer Reviews")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()
